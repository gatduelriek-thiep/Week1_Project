# %% [markdown]
# ## Gatduel's PLP x ILO Journey
# I will be using Jupyter Notebook and Google Colaboratory throughout this journey

# %% [markdown]
# # Let's now start with the print function which will print the following details about me
# <ul>
#   <li>Name</li>
#   <li>Age</li>
#   <li>Favourite_language</li>
#   <li>My goal for this programme</li>
# </ul>

# %%
# Variable for my name
Name = "Gatduel Riek"

# Age variable below
Age = "27"

# Favourite languages
My_favourite_languages = "My favourite languages are: Python, English and Kiswahili"

# My favourite goal
Goal = "I want to work in Data engineering, analysis, science and cybersecurity"

# The below are print functions which will output what is in my variables to the screen

print("Name: ", Name) # This will print my name, which is currently stored in the variable
print("Age: ", Age) # This will print my age
print("Languages: ", My_favourite_languages) # This will print my favourite languages
print("Goal: ", Goal) # This will print my goal or target for this PLP x ILO programme
# Out:
# Name:  Gatduel Riek
# Age:  27
# Languages:  My favourite languages are: Python, English and Kiswahili
# Goal:  I want to work in Data engineering, analysis, science and cybersecurity

# %% [markdown]
# # My Autobiography

# %%
# This variable will store my introduction autobio
autobio = "Hello and my name is Gatduel a data and web scraper\n using Python libraries like BeautifufSoup, requests, selenium and Pandas"

# Now let's use the print function to output the autobio variable
print("Gatduel's Autobiography: ", autobio)
# Out:
# Gatduel's Autobiography:  Hello and my name is Gatduel a data and web scraper
#  using Python libraries like BeautifufSoup, requests, selenium and Pandas
